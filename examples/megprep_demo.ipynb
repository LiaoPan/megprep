# %% [markdown]
# ## MEGPrep Demo
# **Note: The demo examples are presented in JupyterLab.**
# 1. You can run them with one click (⏩︎) or execute them step by step using the Play button (▶︎).
# 2. Running MEGPrep may take a little while. You can directly use megprep_reports.ipynb to access the interactive report.
# 3. Constrained by limited cloud resources, some content might be slow to access.

# %%
# COG-dataset: Auditory evoked fields (AEFs)

# %%
# Run MEGPrep via Docker to perform MEG data preprocessing. (~12 min)
# !docker run -it --rm \
-v "$(pwd)/cog_dataset":/input \
-v "$(pwd)/cog_dataset/derivatives":/output \
-v "$(pwd)/cog_dataset/smri":/smri \
-v /root/megprep/license.txt:/fs_license.txt \
-v "$(pwd)/nextflow_for_cog.config":/program/nextflow/nextflow.config \
cmrlab/megprep:0.0.4 \
-i /input \
-o /output \
--fs_license_file /license.txt \
--fs_subjects_dir /smri \
# --resume
# Out:
# Executor:
# root
# Using configuration file: /program/nextflow/nextflow.config
# Setting dataset_dir in config to: /input
# Setting output_dir in config to: /output
# Using FreeSurfer subjects directory: /smri
# Running Nextflow pipeline...
#
#  N E X T F L O W   ~  version 24.10.3
#
# Launching `/program/nextflow/meg_pipeline.nf` [golden_williams] DSL2 - revision: d850d84ba6
#
# MEG Preprocessing Pipeline
# ...
# Start time: 2025-12-04T21:05:49.652459+08:00
# [-        ] import_MEG_dataset -
#
# [-        ] import_MEG_dataset  -
# [-        ] meg_preproc_osl     -
# [-        ] detect_Artifacts    -
# [-        ] run_ICA             -
# [-        ] run_IC_label        -
# [-        ] apply_ICA           -
# [-        ] epochs              -
# [-        ] compute_covariances -
# [-        ] coregistrations     -
# [-        ] forward_solution    -
# [-        ] source_imaging      -
# fs_anatomy_output.mri_subject_id is not set.
#
# executor >  local (1)
# ...
